# %% [markdown]
# <a href="https://colab.research.google.com/github/Tim120903/lab_1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическое задание №1
#
# Это пример **жирного текста** и *курсивного текста*.
#
# ## Нумерованный список:
# 1. Первый пункт
# 2. Второй пункт
# 3. Третий пункт
#
# ## Маркированный список:
# - Первый элемент
# - Второй элемент
# - Третий элемент
#   - Подэлемент 3.1
#   - Подэлемент 3.2
#
# ## Формула суммы бесконечного геометрического ряда:
#
# Для геометрического ряда с первым членом $a$ и знаменателем $|q| < 1$, сумма вычисляется по формуле:
#
# $S = a/1 - q$
#
# ## Изображение:
# ![Хаги Ваги](data:image/jpeg;base64,...)
