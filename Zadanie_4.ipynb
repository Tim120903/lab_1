# %% [markdown]
# <a href="https://colab.research.google.com/github/Tim120903/lab_1/blob/main/Zadanie_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !mkdir folder1

# %%
# !ls
# Out:
# folder1  sample_data

# %%
# !echo "Текстовый файл" > my_document.txt

# %%
# !ls
# Out:
# folder1  my_document.txt  sample_data

# %%
# !mv my_document.txt folder1/

# %%
# !ls folder1/
# Out:
# my_document.txt

# %%
# !rm folder1/my_document.txt

# %%
# !ls folder1/

# %%
# !clear
