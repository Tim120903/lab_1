# %% [markdown]
# <a href="https://colab.research.google.com/github/Tim120903/lab_1/blob/main/Zadanie_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'

# %%
file_path = "/content/drive/MyDrive/my_text_file.txt"
with open(file_path, "w") as f:
    f.write("Это тестовый файл, сохраненый в Google Drive.\n")
    f.write("Вторая строка.\n")
    f.write("Третья строка.")

print("Файл успешно сохранен в Google Drive.")
# Out:
# Файл успешно сохранен в Google Drive.

# %%
# !ls /content/drive/MyDrive/my_text_file.txt
# Out:
# /content/drive/MyDrive/my_text_file.txt

# %%
with open (file_path, "r") as f:
    content = f.read()
    print("Содержание файла:\n", content)
# Out:
# Содержание файла:
#  Это тестовый файл, сохраненый в Google Drive.
# Вторая строка.
# Третья строка.

# %%
students = [
    ["Оразов Т.С.", 22, "ИВТ-б-о-24-1"],
    ["Каиров В.С.", 19, "ИВТ-б-о-24-1"],
    ["Скоробогатов В.А.", 20, "ИВТ-б-о-24-1"]
]

csv_path = "/content/drive/MyDrive/students.csv"
with open(csv_path, "w") as f:
    for student in students:
        f.write(",".join(map(str, student)) + "\n")

print("Файл students.csv успешно сохранен в Google Drive")
# Out:
# Файл students.csv успешно сохранен в Google Drive

# %%
# !ls /content/drive/MyDrive/*.txt
# Out:
# /content/drive/MyDrive/my_text_file.txt
